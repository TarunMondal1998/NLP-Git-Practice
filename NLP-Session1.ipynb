# %% [markdown]
# ## Loading the dataset and basic Cleaning

# %%
import pandas as pd
import numpy as np
import re
import nltk

# %%
import openpyxl

# %%
## Lading the dataset
data = pd.read_excel("BA_AirlineReviews.xlsx")

# %%
data.head()
# Out:
#    Unnamed: 0  OverallRating Review category  \
# 0           0            1.0        Negative
# 1           1            3.0        Negative
# 2           2            8.0        Positive
# 3           3            1.0        Negative
# 4           4            1.0        Negative
#
#                                ReviewHeader              Name  \
# 0    "Service level far worse then Ryanair"           L Keele
# 1  "do not upgrade members based on status"      Austin Jones
# 2             "Flight was smooth and quick"        M A Collie
# 3             "Absolutely hopeless airline"        Nigel Dean
# 4        "Customer Service is non existent"  Gaylynne Simpson
#
#              Datetime  VerifiedReview  \
# 0  19th November 2023            True
# 1  19th November 2023            True
# 2  16th November 2023           False
# 3  16th November 2023            True
# 4  14th November 2023           False
#
#                                           ReviewBody TypeOfTraveller  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3701 entries, 0 to 3700
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3701 non-null   int64
#  1   OverallRating          3696 non-null   float64
#  2   Review category        3696 non-null   object
#  3   ReviewHeader           3701 non-null   object
#  4   Name                   3701 non-null   object
#  5   Datetime               3701 non-null   object
#  6   VerifiedReview         3701 non-null   bool
#  7   ReviewBody             3701 non-null   object
#  8   TypeOfTraveller        2930 non-null   object
#  9   SeatType               3699 non-null   object
#  10  Route                  2926 non-null   object
#  11  DateFlown              2923 non-null   datetime64[ns]
#  12  SeatComfort            3585 non-null   float64
#  13  CabinStaffService      3574 non-null   float64
# ...

# %%
data_version1 = data[['OverallRating', 'Review category', 'ReviewHeader']]

# %%
data_version1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3701 entries, 0 to 3700
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OverallRating    3696 non-null   float64
#  1   Review category  3696 non-null   object
#  2   ReviewHeader     3701 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 86.9+ KB

# %%
data_version2 = data_version1.iloc[0:1000]

# %%
data_version2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OverallRating    1000 non-null   float64
#  1   Review category  1000 non-null   object
#  2   ReviewHeader     1000 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 23.6+ KB

# %%
data_version2.isnull().sum()
# Out:
# OverallRating      0
# Review category    0
# ReviewHeader       0
# dtype: int64

# %%
data_version2.duplicated().sum()
# Out:
# 5

# %%
data_version2 = data_version2.drop_duplicates()

# %%
data_version2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 995 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OverallRating    995 non-null    float64
#  1   Review category  995 non-null    object
#  2   ReviewHeader     995 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 31.1+ KB

# %%
data_version2.to_excel("data_version2.xlsx")
# Out:
# C:\Users\tarun\AppData\Local\Temp\ipykernel_23568\2026884649.py:1: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '3.0.3' currently installed).
#   data_version2.to_excel("data_version2.xlsx")
