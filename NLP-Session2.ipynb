# %% [markdown]
# ## Text Cleaning

# %%
import pandas as pd
import numpy as np
import re
import nltk
import openpyxl

# %%
data_cleaning = pd.read_excel("data_version2.xlsx")

# %%
data_cleaning.head()
# Out:
#    Unnamed: 0 Review category                              ReviewHeader  \
# 0           0        Negative    "Service level far worse then Ryanair"
# 1           1        Negative  "do not upgrade members based on status"
# 2           2        Positive             "Flight was smooth and quick"
# 3           3        Negative             "Absolutely hopeless airline"
# 4           4        Negative        "Customer Service is non existent"
#
#                                           ReviewBody
# 0  4 Hours before takeoff we received a Mail stat...
# 1  I recently had a delay on British Airways from...
# 2  Boarded on time, but it took ages to get to th...
# 3  5 days before the flight, we were advised by B...
# 4  We traveled to Lisbon for our dream vacation, ...

# %%
data_cleaning = data_cleaning.drop(['Unnamed: 0'], axis = 1)

# %%
data_cleaning.head()
# Out:
#   Review category                              ReviewHeader  \
# 0        Negative    "Service level far worse then Ryanair"
# 1        Negative  "do not upgrade members based on status"
# 2        Positive             "Flight was smooth and quick"
# 3        Negative             "Absolutely hopeless airline"
# 4        Negative        "Customer Service is non existent"
#
#                                           ReviewBody
# 0  4 Hours before takeoff we received a Mail stat...
# 1  I recently had a delay on British Airways from...
# 2  Boarded on time, but it took ages to get to th...
# 3  5 days before the flight, we were advised by B...
# 4  We traveled to Lisbon for our dream vacation, ...
